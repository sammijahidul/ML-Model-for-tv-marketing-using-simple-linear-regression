# %%
import pandas as pd

# %%
data_file = pd.read_csv('tvmarketing.csv')

# %%
data_file.head()
# Out:
#       TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9

# %%
import seaborn as sns

# %%
sns.pairplot(data_file)
